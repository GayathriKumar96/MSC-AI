# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from load_dataset_vars import *
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       2 from sklearn.linear_model import LogisticRegression
#       3 from sklearn.metrics import accuracy_score
# ----> 4 from load_dataset_vars import *
#
# File /home/centos/Project/Notebooks/load_dataset_vars.py:6
#       4 #Load the dataframe first 200 rows
#       5 data = pd.read_csv('../Dataset/preprocessed_dataset.csv', usecols=['text','label1'], nrows=200),
# ----> 6 data = data.rename(columns={'label1': 'label'})
#       8 # Split data into train and test sets
#       9 X_train, X_test, y_train, y_test = train_test_split(data["text"], data["label"], test_size=0.2, random_state=42)
#
# AttributeError: 'tuple' object has no attribute 'rename'

# %%
# Feature extraction using TF-IDF
vectorizer = TfidfVectorizer(max_features=10000, ngram_range=(1, 2))
X_train_features = vectorizer.fit_transform(X_train)
X_test_features = vectorizer.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 # Feature extraction using TF-IDF
#       2 vectorizer = TfidfVectorizer(max_features=10000, ngram_range=(1, 2))
# ----> 3 X_train_features = vectorizer.fit_transform(X_train)
#       4 X_test_features = vectorizer.transform(X_test)
#
# File /opt/anaconda3/envs/my_env/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:2091, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2084 self._check_params()
#    2085 self._tfidf = TfidfTransformer(
#    2086     norm=self.norm,
#    2087     use_idf=self.use_idf,
#    2088     smooth_idf=self.smooth_idf,
#    2089     sublinear_tf=self.sublinear_tf,
#    2090 )
# -> 2091 X = super().fit_transform(raw_documents)
#    2092 self._tfidf.fit(X)
#    2093 # X is already a transformed view of raw_documents so
#    2094 # we set copy to False
#
# File /opt/anaconda3/envs/my_env/lib/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/my_env/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:1372, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1364             warnings.warn(
#    1365                 "Upper case characters found in"
#    1366                 " vocabulary while 'lowercase'"
#    1367                 " is True. These entries will not"
#    1368                 " be matched with any documents"
#    1369             )
#    1370             break
# -> 1372 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1374 if self.binary:
#    1375     X.data.fill(1)
#
# File /opt/anaconda3/envs/my_env/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:1257, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1255 values = _make_int_array()
#    1256 indptr.append(0)
# -> 1257 for doc in raw_documents:
#    1258     feature_counter = {}
#    1259     for feature in analyze(doc):
#
# TypeError: 'NoneType' object is not iterable

# %%
# Train a Logistic Regression model
classifier = LogisticRegression(solver="lbfgs", C=1.0)
classifier.fit(X_train_features, y_train)
# Out:
# LogisticRegression()

# %%
# Evaluate model performance on test set
y_pred = classifier.predict(X_test_features)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on test set: {accuracy:.4f}")
# Out:
# Accuracy on test set: 0.5250
